# %%
# This bit of code allows me to output more than one variable value without using a print statement.
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# #  Numbers and Booleans

# %% [markdown]
# Compute the number of bytes in one Gigabyte (1kb = 1024 bytes, 1mb = 1024 kb, 1gb = 1024 mb)

# %%
#Write your code here
byte = 1
kbyte = 1024 * byte
mbyte = 1024 * kbyte
gbyte = 1024 * mbyte
gbyte
# Out:
# 1073741824

# %% [markdown]
# You bought 500 shares of stock A at \$600 on day 0 and you sold it at \$1000 on day 700
# The daily discount rate is 0.01%. How much profit did you make in terms of net present value.

# %%
# (Sellp X Shares)/((1+dr)^700) - (buyP X Shares)

shares = 500
buyp = 600
sellp = 1000
buyd= 0
selld = 700
dr = 0.01/100

npv = (sellp)*shares/(1+dr)**(selld) - buyp*shares

npv
# Out:
# 166198.54153624648

# %% [markdown]
# Boolean values are useful when we compare multiple variables. Some common operators:
#
# - `==`, `<`, `<=`, `>`, `>=`
# - `and`, `or`, `not`

# %% [markdown]
# For any value of x, create a variable called even_check that is True if x is even and False if x is odd.

# %%
#Write your code here
x=15
even_check = (x % 2 == 0)
even_check
# Out:
# False

# %% [markdown]
# # Strings
#
#
# Create a variable called "name" that stores your full name. Find whether your name has an even or odd number of letters.

# %%
#TA Solution
first_name = 'Ningyuan'
last_name = 'Chen'
name = first_name + last_name
name

len(name) % 2                     # 0 if even
# Out:
# 'NingyuanChen'
# 0

# %%
#Write your code here
first_name = 'William'
middle_name = 'Nicholas'
last_name = 'Husic'

len(first_name + middle_name + last_name) % 2
# Out:
# 0

# %% [markdown]
# Correct the following variable so it is equal to "spammy"

# %%
#Write your code here
s = 'spaxxy'
s = s[0:3] + "mm" + s[-1]
s
# Out:
# 'spammy'

# %% [markdown]
# ---

# %% [markdown]
# We can check if a character is in a string using **in**. There is also a **not in**.  The result return a boolean.

# %%
number = '13579'

'135' in number

'15' in number
# Out:
# True
# False
