# %%
import pandas as pd

df = pd.read_csv('Airline_Customers.csv')
df.head(10)
# Out:
#       id  Gender      Customer_Type  Age   Type_of_Travel     Class  \
# 0  19556  Female     Loyal Customer   52  Business travel       Eco
# 1  90035  Female     Loyal Customer   36  Business travel  Business
# 2  12360    Male  disloyal Customer   20  Business travel       Eco
# 3  77959    Male     Loyal Customer   44  Business travel  Business
# 4  36875  Female     Loyal Customer   49  Business travel       Eco
# 5  39177    Male     Loyal Customer   16  Business travel       Eco
# 6  79433  Female     Loyal Customer   77  Business travel  Business
# 7  97286  Female     Loyal Customer   43  Business travel  Business
# 8  27508    Male     Loyal Customer   47  Business travel       Eco
# 9  62482  Female     Loyal Customer   46  Business travel  Business
#
#    Flight_Distance
# 0              160
# 1             2863
# 2              192
# 3             3377
# 4             1182
# 5              311
# 6             3987
# 7             2556
# 8              556
# ...

# %%
# Q1
df_sorted = df.sort_values(by='Age', ascending=False)
df_sorted
# Out:
#            id  Gender      Customer_Type  Age   Type_of_Travel     Class  \
# 4002   100562    Male  disloyal Customer   85  Business travel  Business
# 11983  117306  Female     Loyal Customer   85  Business travel  Business
# 7628    43895  Female     Loyal Customer   85  Business travel  Business
# 15467   32729  Female  disloyal Customer   85  Business travel  Business
# 18140   44737    Male     Loyal Customer   85  Business travel  Eco Plus
# ...       ...     ...                ...  ...              ...       ...
# 5091   111933    Male     Loyal Customer    7  Personal Travel  Business
# 17076   69763  Female     Loyal Customer    7  Personal Travel       Eco
# 4831     3433    Male     Loyal Customer    7  Personal Travel       Eco
# 3890    28193  Female     Loyal Customer    7  Personal Travel       Eco
# 14861   75351    Male     Loyal Customer    7  Personal Travel       Eco
#
#        Flight_Distance
# 4002               486
# 11983              325
# ...

# %%
# (i)
print(df['Flight_Distance'].mean())

# (ii)
print(df[df['Customer_Type'] == 'Loyal Customer']['Flight_Distance'].mean())

# (iii)
print(df[df['Customer_Type'] == 'disloyal Customer']['Flight_Distance'].mean())
# Out:
# 1193.788458577148
# 1302.8012466355008
# 712.7374453011043

# %%
df.groupby('Class')['Flight_Distance'].mean()
# Out:
# Class
# Business    1676.530772
# Eco          746.255621
# Eco Plus     746.946792
# Name: Flight_Distance, dtype: float64

# %%
# Q3
df_female = df[df['Gender'] == 'Female']
# df_female.shape[0]
# len(df[df['Gender'] == 'Female'])
# Out:
# 13172

# %%
# Q7
max_dist = df['Flight_Distance'].max()
df[df['Flight_Distance'] == max_dist]['id']
# Out:
# 7851     31874
# 11779    31816
# 14261    31872
# 14615    31815
# Name: id, dtype: int64
